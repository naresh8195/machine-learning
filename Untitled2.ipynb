# %%
import pandas as pd
import numpy as np

data={
    'Company':['Google','Microsoft','Facebool','Royal'],
    'Person': ['Karan','Nila','Naresh','Dhusendiran'],
    'Sales': [200,300,400,500]

}

df = pd.DataFrame(data)

df
# Out:
#      Company       Person  Sales
# 0     Google        Karan    200
# 1  Microsoft         Nila    300
# 2   Facebool       Naresh    400
# 3      Royal  Dhusendiran    500

# %%
byComp = df.groupby('Company')

df.mean(numeric_only=True)
# Out:
# Sales    350.0
# dtype: float64

# %%
byComp.sum()
# Out:
#                 Person  Sales
# Company
# Facebool        Naresh    400
# Google           Karan    200
# Microsoft         Nila    300
# Royal      Dhusendiran    500

# %%
df['Sales'].std()
# Out:
# 129.09944487358058

# %%
df.groupby('Company').count()
# Out:
#            Person  Sales
# Company
# Facebool        1      1
# Google          1      1
# Microsoft       1      1
# Royal           1      1

# %%
df.groupby('Company').describe()
# Out:
#           Sales
#           count   mean std    min    25%    50%    75%    max
# Company
# Facebool    1.0  400.0 NaN  400.0  400.0  400.0  400.0  400.0
# Google      1.0  200.0 NaN  200.0  200.0  200.0  200.0  200.0
# Microsoft   1.0  300.0 NaN  300.0  300.0  300.0  300.0  300.0
# Royal       1.0  500.0 NaN  500.0  500.0  500.0  500.0  500.0

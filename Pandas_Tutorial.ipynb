# %% [markdown]
# ### Author : Sanjoy Biswas
# ### Topic : Pandas Tutorial: DataFrames in Python
# ### Email : sanjoy.eee32@gmail.com

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # missing data

# %%
d = {
    'A': [1,2, np.nan],
    'B':[5, np.nan, np.nan],
    'C':[1,2,3]
}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %% [markdown]
# ## drop nan method

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis = 0)
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna??

# %%
df.dropna(axis = 1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %% [markdown]
# ## filling value

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.fillna(value = 'Filling Value')
# Out:
#                A              B  C
# 0            1.0            5.0  1
# 1            2.0  Filling Value  2
# 2  Filling Value  Filling Value  3

# %%
df = pd.DataFrame(d)

# %%
a = df['A'].fillna(value = df['A'].mean())

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
a
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df['A'].fillna(value = df['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.fillna??

# %%
df['A'].fillna(value = df['A'].mean(), inplace = True)
# Out:
# /tmp/ipython-input-43-2171742998.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['A'].fillna(value = df['A'].mean(), inplace = True)

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  1.5  NaN  3

# %% [markdown]
# # Group By

# %%
data = {
    'Company':['Google', 'Google', 'MSFT', 'FB','FB','IBM'],
    'Person': ['Sam','Nihad','Any','Van','Rakib','Ovi'],
    'Sales': [200, 120, 340, 124, 243, 350]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Company Person  Sales
# 0  Google    Sam    200
# 1  Google  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IBM    Ovi    350

# %%
byComp = df.groupby('Company')

# %%
byComp.mean(numeric_only=True)
# Out:
#          Sales
# Company
# FB       183.5
# Google   160.0
# IBM      350.0
# MSFT     340.0

# %%
byComp.sum()
# Out:
#            Person  Sales
# Company
# FB       VanRakib    367
# Google   SamNihad    320
# IBM           Ovi    350
# MSFT          Any    340

# %%
df
# Out:
#   Company Person  Sales
# 0  Google    Sam    200
# 1  Google  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IBM    Ovi    350

# %%
df['Sales'].std()
# Out:
# 100.89945490437498

# %%
df.groupby('Company').count()
# Out:
#          Person  Sales
# Company
# FB            2      2
# Google        2      2
# IBM           1      1
# MSFT          1      1

# %%
df

# %%
df.groupby('Company').describe()

# %% [markdown]
# # Merging, Joining and Concatenating

# %% [markdown]
# ## Concatenating

# %%
df1 = pd.DataFrame(np.random.randint(1, 20, size = (4, 3)), [1,2,3,4], ['W', 'X', 'Y'])

# %%
df2 = pd.DataFrame(np.random.randint(20,40, size = (4, 3)), [5,6,7,8], ['W', 'X', 'Y'])

# %%
df3 = pd.DataFrame(np.random.randint(40,60, size = (4, 3)), [9,10,11,12], ['W', 'X', 'Y'])

# %%
df1
# Out:
#     W   X   Y
# 1   4   7   5
# 2   6   9   4
# 3  12  13   4
# 4  17  10  17

# %%
df2
# Out:
#     W   X   Y
# 5  30  29  37
# 6  31  28  24
# 7  36  21  34
# 8  25  27  34

# %%
df3
# Out:
#      W   X   Y
# 9   52  53  52
# 10  41  54  51
# 11  59  50  58
# 12  54  47  52

# %%
farme = [df1, df2, df3]

# %%
pd.concat(farme)
# Out:
#      W   X   Y
# 1    4   7   5
# 2    6   9   4
# 3   12  13   4
# 4   17  10  17
# 5   30  29  37
# 6   31  28  24
# 7   36  21  34
# 8   25  27  34
# 9   52  53  52
# 10  41  54  51
# 11  59  50  58
# 12  54  47  52

# %%
pd.concat(farme, axis = 1)
# Out:
#        W     X     Y     W     X     Y     W     X     Y
# 1    4.0   7.0   5.0   NaN   NaN   NaN   NaN   NaN   NaN
# 2    6.0   9.0   4.0   NaN   NaN   NaN   NaN   NaN   NaN
# 3   12.0  13.0   4.0   NaN   NaN   NaN   NaN   NaN   NaN
# 4   17.0  10.0  17.0   NaN   NaN   NaN   NaN   NaN   NaN
# 5    NaN   NaN   NaN  30.0  29.0  37.0   NaN   NaN   NaN
# 6    NaN   NaN   NaN  31.0  28.0  24.0   NaN   NaN   NaN
# 7    NaN   NaN   NaN  36.0  21.0  34.0   NaN   NaN   NaN
# 8    NaN   NaN   NaN  25.0  27.0  34.0   NaN   NaN   NaN
# 9    NaN   NaN   NaN   NaN   NaN   NaN  52.0  53.0  52.0
# 10   NaN   NaN   NaN   NaN   NaN   NaN  41.0  54.0  51.0
# 11   NaN   NaN   NaN   NaN   NaN   NaN  59.0  50.0  58.0
# 12   NaN   NaN   NaN   NaN   NaN   NaN  54.0  47.0  52.0

# %% [markdown]
# ## Merging

# %%
left = {
    'key':['k0','k1','k2','k3'],
    'A':[10,20,30,40],
    'B':[1,2,3,4]
}

# %%
right = {
    'key':['k0','k1','k2','k3'],
    'C':[100,200,300,400],
    'D':[11,12,13,14]
}

# %%
left = pd.DataFrame(left)

# %%
right = pd.DataFrame(right)

# %%
left
# Out:
#   key   A  B
# 0  k0  10  1
# 1  k1  20  2
# 2  k2  30  3
# 3  k3  40  4

# %%
right
# Out:
#   key    C   D
# 0  k0  100  11
# 1  k1  200  12
# 2  k2  300  13
# 3  k3  400  14

# %%
pd.merge(left, right, on='key')
# Out:
#   key   A  B    C   D
# 0  k0  10  1  100  11
# 1  k1  20  2  200  12
# 2  k2  30  3  300  13
# 3  k3  40  4  400  14

# %%
pd.merge??

# %% [markdown]
# ## Joining

# %%
left = {
    'A':['A0','A1','A2'],
    'B':['B0','B1','B2']
}

# %%
right = {
    'C':['C0','C2','C3'],
    'D':['D0','D2','D3']
}

# %%
left = pd.DataFrame(left, index = ['k0','k1','k2'])

# %%
right = pd.DataFrame(right, index = ['k0','k2','k3'])

# %%
left
# Out:
#      A   B
# k0  A0  B0
# k1  A1  B1
# k2  A2  B2

# %%
right
# Out:
#      C   D
# k0  C0  D0
# k2  C2  D2
# k3  C3  D3

# %%
left.join(right, how = 'inner')
# Out:
#      A   B   C   D
# k0  A0  B0  C0  D0
# k2  A2  B2  C2  D2

# %%
left.join??

# %% [markdown]
# # Operations

# %%
df = pd.DataFrame({
    'col1':[444,555,666,444],
    'col2':[1,2,3,4],
    'col3':['abc','def','ghi','xyz']
})

# %%
df
# Out:
#    col1  col2 col3
# 0   444     1  abc
# 1   555     2  def
# 2   666     3  ghi
# 3   444     4  xyz

# %%
df['col1'].unique()

# %%
df['col1'].nunique()

# %%
df['col1'].value_counts()

# %% [markdown]
# ## Apply Method

# %%
def times2(x):
    return 2*x

# %%
df['col2'].apply(times2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col2, dtype: int64

# %%
df['col2'].apply(lambda x: x**2)
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# Name: col2, dtype: int64

# %% [markdown]
# # Reading File

# %%
df = pd.read_excel('/content/SampleData.xlsx')

# %%
df
# Out:
#     Unnamed: 0 Unnamed: 1                                         Unnamed: 2
# 0          NaN        NaN                                                NaN
# 1          NaN        NaN                                                NaN
# 2          NaN        NaN                                                NaN
# 3          NaN        NaN                            Online Instruction Page
# 4          NaN        NaN                              Sample Data for Excel
# 5          NaN        NaN                                                NaN
# 6          NaN        NaN                                  Related tutorials
# 7          NaN        NaN                                 Named Excel Tables
# 8          NaN        NaN                                    Data Entry Tips
# 9          NaN        NaN                            More Excel Sample Files
# 10         NaN        NaN                                                NaN
# 11         NaN        NaN                       Related Contextures Products
# 12         NaN        NaN                     Contextures Excel Tools Add-in
# 13         NaN        NaN                               Data Entry Popup Kit
# 14         NaN        NaN                                                NaN
# 15         NaN        NaN  Get weekly Excel tips, tutorials, videos, and ...
# 16         NaN        NaN                       Contextures Excel Newsletter
# 17         NaN        NaN                                                NaN
# 18         NaN        NaN                                              Notes
# 19         NaN          •  SalesOrders sheet has sales data for a fiction...
# 20         NaN          •  The Total column could be changed to a formula...

# %%
df.head(10)
# Out:
#    Unnamed: 0 Unnamed: 1               Unnamed: 2
# 0         NaN        NaN                      NaN
# 1         NaN        NaN                      NaN
# 2         NaN        NaN                      NaN
# 3         NaN        NaN  Online Instruction Page
# 4         NaN        NaN    Sample Data for Excel
# 5         NaN        NaN                      NaN
# 6         NaN        NaN        Related tutorials
# 7         NaN        NaN       Named Excel Tables
# 8         NaN        NaN          Data Entry Tips
# 9         NaN        NaN  More Excel Sample Files

# %%
df.tail()
# Out:
#     Unnamed: 0 Unnamed: 1                                         Unnamed: 2
# 16         NaN        NaN                       Contextures Excel Newsletter
# 17         NaN        NaN                                                NaN
# 18         NaN        NaN                                              Notes
# 19         NaN          •  SalesOrders sheet has sales data for a fiction...
# 20         NaN          •  The Total column could be changed to a formula...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2'], dtype='object')

# %%
df.columns.to_list()
# Out:
# ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      float64
#  1   Unnamed: 1  2 non-null      object
#  2   Unnamed: 2  14 non-null     object
# dtypes: float64(1), object(2)
# memory usage: 636.0+ bytes

# %%
df.nunique()
# Out:
# Unnamed: 0     0
# Unnamed: 1     1
# Unnamed: 2    14
# dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0 Unnamed: 1               Unnamed: 2
# 0         NaN        NaN                      NaN
# 1         NaN        NaN                      NaN
# 2         NaN        NaN                      NaN
# 3         NaN        NaN  Online Instruction Page
# 4         NaN        NaN    Sample Data for Excel

# %%
df['20% Dis'] = df['Total'].apply(lambda x: x*(20/100))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-106-2706850078.py in <cell line: 0>()
# ----> 1 df['20% Dis'] = df['Total'].apply(lambda x: x*(20/100))
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Total'

# %%
df.head()
# Out:
#    Unnamed: 0 Unnamed: 1               Unnamed: 2
# 0         NaN        NaN                      NaN
# 1         NaN        NaN                      NaN
# 2         NaN        NaN                      NaN
# 3         NaN        NaN  Online Instruction Page
# 4         NaN        NaN    Sample Data for Excel

# %%
df['Payment'] = df['Total'] - df['20% Dis']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-109-2940426344.py in <cell line: 0>()
# ----> 1 df['Payment'] = df['Total'] - df['20% Dis']
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Total'

# %%
df.head()
# Out:
#    Unnamed: 0 Unnamed: 1               Unnamed: 2
# 0         NaN        NaN                      NaN
# 1         NaN        NaN                      NaN
# 2         NaN        NaN                      NaN
# 3         NaN        NaN  Online Instruction Page
# 4         NaN        NaN    Sample Data for Excel

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (12,6))
plt.plot(df['OrderDate'], df['Total'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'OrderDate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-112-4078925427.py in <cell line: 0>()
#       1 plt.figure(figsize = (12,6))
# ----> 2 plt.plot(df['OrderDate'], df['Total'])
#       3 plt.show()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'OrderDate'
